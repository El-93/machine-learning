# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df =pd.read_csv('/content/drive/MyDrive/heart.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df1=df.rename(columns={'cp':'chest_pain_type', 'trestbps':'resting_blood_pressure', 'chol': 'cholesterol','fbs': 'fasting_blood_sugar', 
                       'restecg' : 'resting_electrocardiogram', 'thalach': 'max_heart_rate_achieved', 'exang': 'exercise_induced_angina',
                       'oldpeak': 'st_depression', 'slope': 'st_slope', 'ca':'num_major_vessels', 'thal': 'thalassemia'}, errors="raise")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        1025 non-null   int64
#  1   sex                        1025 non-null   int64
#  2   chest_pain_type            1025 non-null   int64
#  3   resting_blood_pressure     1025 non-null   int64
#  4   cholesterol                1025 non-null   int64
#  5   fasting_blood_sugar        1025 non-null   int64
#  6   resting_electrocardiogram  1025 non-null   int64
#  7   max_heart_rate_achieved    1025 non-null   int64
#  8   exercise_induced_angina    1025 non-null   int64
#  9   st_depression              1025 non-null   float64
#  10  st_slope                   1025 non-null   int64
#  11  num_major_vessels          1025 non-null   int64
#  12  thalassemia                1025 non-null   int64
# ...

# %%
df1.head()
# Out:
#    age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0   52    1                0                     125          212
# 1   53    1                0                     140          203
# 2   70    1                0                     145          174
# 3   61    1                0                     148          203
# 4   62    0                0                     138          294
#
#    fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 0                    0                          1                      168
# 1                    1                          0                      155
# 2                    0                          1                      125
# 3                    0                          1                      161
# 4                    1                          1                      106
#
#    exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# ...

# %%
df1.shape
# Out:
# (1025, 14)

# %%
df1.isnull().sum()
# Out:
# age                          0
# sex                          0
# chest_pain_type              0
# resting_blood_pressure       0
# cholesterol                  0
# fasting_blood_sugar          0
# resting_electrocardiogram    0
# max_heart_rate_achieved      0
# exercise_induced_angina      0
# st_depression                0
# st_slope                     0
# num_major_vessels            0
# thalassemia                  0
# target                       0
# dtype: int64

# %%
df1['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df1['target'].value_counts()/df1.shape[0]*100
# Out:
# 1    51.317073
# 0    48.682927
# Name: target, dtype: float64

# %%
df1.corr()['target'].sort_values(ascending=False)
# Out:
# target                       1.000000
# chest_pain_type              0.434854
# max_heart_rate_achieved      0.422895
# st_slope                     0.345512
# resting_electrocardiogram    0.134468
# fasting_blood_sugar         -0.041164
# cholesterol                 -0.099966
# resting_blood_pressure      -0.138772
# age                         -0.229324
# sex                         -0.279501
# thalassemia                 -0.337838
# num_major_vessels           -0.382085
# exercise_induced_angina     -0.438029
# st_depression               -0.438441
# Name: target, dtype: float64

# %%
mypal=['#FC05FB', '#FEAEFE', '#FCD2FC','#F3FEFA', '#B4FFE4','#3FFEBA']
plt.figure(figsize=(7,5),facecolor='#F6F5F4')
ax=sns.countplot(x=df['target'],palette=mypal[1::4])

ax.set_title("Target variable distribution", fontsize=20, y=1.05)
# Out:
# Text(0.5, 1.05, 'Target variable distribution')

# %%
corr_df1=df1[['chest_pain_type','max_heart_rate_achieved','st_slope','resting_electrocardiogram']]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr_df1.corr(),annot=True,linewidth=2)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15, 6))
sns.scatterplot(data=df1)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df1, x='max_heart_rate_achieved', y='resting_blood_pressure', hue='target')
# Out:
# <Axes: xlabel='max_heart_rate_achieved', ylabel='resting_blood_pressure'>

# %%
categorical_features = ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']
numerical_features = ['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']
print('Categorical Features are : ', categorical_features)
print('Continuous Features are : ', numerical_features)
# Out:
# Categorical Features are :  ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']
# Continuous Features are :  ['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']
# Categorical Features are :  ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']
# Continuous Features are :  ['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']

# %%
sns.pairplot(df1[['age', 'resting_blood_pressure', 'cholesterol', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']])

# %%
sns.pairplot(df1[['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']])

# %%
sns.pairplot(df1[['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_electrocardiogram', 'exercise_induced_angina', 'st_slope', 'thalassemia']])

# %%
sns.boxplot(df1, x='target', y='age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
df1[(df1['age'] == 35)  & (df1['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 254   35    1                0                     120          198
# 384   35    1                0                     126          282
# 695   35    1                0                     126          282
# 699   35    1                0                     126          282
# 701   35    1                0                     120          198
# 711   35    1                0                     120          198
# 912   35    1                0                     120          198
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 254                    0                          1                      130
# 384                    0                          0                      156
# 695                    0                          0                      156
# 699                    0                          0                      156
# ...

# %%
index_drop_age_0 = df1[(df1['age'] == 35)  & (df1['target'] == 0)].index
df1 = df1.drop(index_drop_age_0, axis = 0)

# %%
sns.boxplot(df1, x='target', y='resting_blood_pressure')
# Out:
# <Axes: xlabel='target', ylabel='resting_blood_pressure'>

# %%
df1[(df1['resting_blood_pressure'] >= 190) & (df1['resting_blood_pressure'] <= 200) & (df1['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 151   54    1                1                     192          283
# 175   56    0                0                     200          288
# 246   54    1                1                     192          283
# 294   56    0                0                     200          288
# 326   54    1                1                     192          283
# 508   56    0                0                     200          288
# 688   56    0                0                     200          288
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 151                    0                          0                      195
# 175                    1                          0                      133
# 246                    0                          0                      195
# 294                    1                          0                      133
# ...

# %%
index_drop_resting_blood_pressure_0 = df1[(df1['resting_blood_pressure'] >= 190) & (df1['resting_blood_pressure'] <= 200) & (df1['target'] == 0)].index
df1 = df1.drop(index_drop_resting_blood_pressure_0, axis = 0)

# %%
df1[(df1['resting_blood_pressure'] >= 170) & (df1['resting_blood_pressure'] <= 185) & (df1['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 137   64    0                0                     180          325
# 203   64    1                3                     170          227
# 235   64    1                3                     170          227
# 257   64    0                0                     180          325
# 343   52    1                2                     172          199
# 528   59    1                3                     178          270
# 539   64    1                3                     170          227
# 624   59    1                3                     178          270
# 837   52    1                2                     172          199
# 872   64    1                3                     170          227
# 891   64    0                0                     180          325
# 896   59    1                3                     178          270
# 971   52    1                2                     172          199
#
# ...

# %%
index_drop_resting_blood_pressure_1 = df1[(df1['resting_blood_pressure'] >= 170) & (df1['resting_blood_pressure'] <= 185) & (df1['target'] == 1)].index
df1 = df1.drop(index_drop_resting_blood_pressure_1, axis = 0)

# %%
sns.boxplot(df1, x='target', y='cholesterol')
# Out:
# <Axes: xlabel='target', ylabel='cholesterol'>

# %%
df1[(df1['cholesterol'] >= 400) & (df1['cholesterol'] <= 410) & (df1['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 179   56    0                0                     134          409
# 450   63    0                0                     150          407
# 481   63    0                0                     150          407
# 641   56    0                0                     134          409
# 685   63    0                0                     150          407
# 889   63    0                0                     150          407
# 996   56    0                0                     134          409
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 179                    0                          0                      150
# 450                    0                          0                      154
# 481                    0                          0                      154
# 641                    0                          0                      150
# ...

# %%
index_drop_cholesterol_0 = df1[(df1['cholesterol'] >= 400) & (df1['cholesterol'] <= 410) & (df1['target'] == 0)].index
df1 = df1.drop(index_drop_cholesterol_0, axis = 0)

# %%
df1[(df1['cholesterol'] >= 350) & (df1['cholesterol'] <= 450) & (df1['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 40    65    0                2                     160          360
# 123   65    0                2                     140          417
# 167   57    0                0                     120          354
# 255   62    0                0                     140          394
# 419   65    0                2                     160          360
# 422   57    0                0                     120          354
# 435   57    0                0                     120          354
# 542   62    0                0                     140          394
# 578   62    0                0                     140          394
# 665   65    0                2                     140          417
# 751   65    0                2                     160          360
# 958   65    0                2                     140          417
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# ...

# %%
index_drop_cholesterol_1 = df1[(df1['cholesterol'] >= 350) & (df1['cholesterol'] <= 450) & (df1['target'] == 1)].index
df1 = df1.drop(index_drop_cholesterol_1, axis = 0)

# %%
df1[(df1['cholesterol'] < 600) & (df1['target'] == 1)].tail(10)
# Out:
#       age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 1003   52    1                0                     108          233
# 1004   51    0                2                     140          308
# 1006   58    1                2                     140          211
# 1007   56    1                3                     120          193
# 1008   42    1                1                     120          295
# 1011   45    1                1                     128          308
# 1014   44    0                2                     108          141
# 1019   47    1                0                     112          204
# 1020   59    1                1                     140          221
# 1023   50    0                0                     110          254
#
#       fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 1003                    1                          1                      147
# ...

# %%
index_drop_cholesterol_1 = df1[(df1['cholesterol'] < 600) & (df1['target'] == 1)].tail(10).index
df1 = df1.drop(index_drop_cholesterol_1, axis = 0)

# %%
sns.boxplot(df1, x='target', y='max_heart_rate_achieved')
# Out:
# <Axes: xlabel='target', ylabel='max_heart_rate_achieved'>

# %%
df1[(df1['max_heart_rate_achieved'] < 80) & (df1['target'] == 0)].head(40)
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 267   67    1                0                     120          237
# 296   67    1                0                     120          237
# 378   67    1                0                     120          237
# 559   67    1                0                     120          237
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 267                    0                          1                       71
# 296                    0                          1                       71
# 378                    0                          1                       71
# 559                    0                          1                       71
#
#      exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 267                        0            1.0         1                  0
# 296                        0            1.0         1                  0
# ...

# %%
index_drop_max_heart_rate_achieved_0 = df1[(df1['max_heart_rate_achieved'] < 80) & (df1['target'] == 0)].head(40).index
df1 = df1.drop(index_drop_max_heart_rate_achieved_0, axis = 0)

# %%
df1[(df1['max_heart_rate_achieved'] >= 90) & (df1['max_heart_rate_achieved'] <= 100) & (df1['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 708   60    0                2                     120          178
# 793   60    0                2                     120          178
# 967   60    0                2                     120          178
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 708                    1                          1                       96
# 793                    1                          1                       96
# 967                    1                          1                       96
#
#      exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 708                        0            0.0         2                  0
# 793                        0            0.0         2                  0
# 967                        0            0.0         2                  0
#
#      thalassemia  target
# 708            2       1
# 793            2       1
# ...

# %%
index_drop_max_heart_rate_achieved_1 = df1[(df1['max_heart_rate_achieved'] >= 90) & (df1['max_heart_rate_achieved'] <= 100) & (df1['target'] == 1)].index
df1 = df1.drop(index_drop_max_heart_rate_achieved_1, axis = 0)

# %%
df1[(df1['max_heart_rate_achieved'] >= 100) & (df1['max_heart_rate_achieved'] <= 110) & (df1['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 38    64    1                0                     128          263
# 642   64    1                0                     128          263
# 983   64    1                0                     128          263
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 38                     0                          1                      105
# 642                    0                          1                      105
# 983                    0                          1                      105
#
#      exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 38                         1            0.2         1                  1
# 642                        1            0.2         1                  1
# 983                        1            0.2         1                  1
#
#      thalassemia  target
# 38             3       1
# 642            3       1
# ...

# %%
index_drop_max_heart_rate_achieved_1 = df1[(df1['max_heart_rate_achieved'] >= 100) & (df1['max_heart_rate_achieved'] <= 110) & (df1['target'] == 1)].index
df1 = df1.drop(index_drop_max_heart_rate_achieved_1, axis = 0)

# %%
sns.boxplot(df1, x='target', y='st_depression')
# Out:
# <Axes: xlabel='target', ylabel='st_depression'>

# %%
df1[(df1['st_depression'] >= 5.5) & (df1['st_depression'] <= 6.5) & (df1['target'] == 0)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 54    55    1                0                     140          217
# 55    55    1                0                     140          217
# 69    62    0                0                     160          164
# 393   62    0                0                     160          164
# 526   62    0                0                     160          164
# 613   55    1                0                     140          217
# 833   55    1                0                     140          217
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 54                     0                          1                      111
# 55                     0                          1                      111
# 69                     0                          0                      145
# 393                    0                          0                      145
# ...

# %%
index_drop_st_depression_0 =df1[(df1['st_depression'] >= 5.5) & (df1['st_depression'] <= 6.5) & (df1['target'] == 0)].index
df1 = df1.drop(index_drop_st_depression_0, axis = 0)

# %%
df1[(df1['st_depression'] >= 2.5) & (df1['st_depression'] < 4) & (df1['target'] == 1)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 22    45    1                0                     104          208
# 265   45    1                0                     104          208
# 332   37    1                2                     130          250
# 433   37    1                2                     130          250
# 652   66    0                3                     150          226
# 664   66    0                3                     150          226
# 713   66    0                3                     150          226
# 851   37    1                2                     130          250
# 913   45    1                0                     104          208
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 22                     0                          0                      148
# 265                    0                          0                      148
# ...

# %%
index_drop_st_depression_1 =df1[(df1['st_depression'] >= 2.5) & (df1['st_depression'] < 4) & (df1['target'] == 1)].index
df1 = df1.drop(index_drop_st_depression_1, axis = 0)

# %%
sns.boxplot(df1, x='target', y='num_major_vessels')
# Out:
# <Axes: xlabel='target', ylabel='num_major_vessels'>

# %%
num_vessels_list=[1,2,3,4,5]
df1[(df1['target'] == 1) & df1['num_major_vessels'].isin(num_vessels_list)]
# Out:
#      age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 16    51    0                2                     140          308
# 21    67    0                0                     106          223
# 36    51    1                3                     125          213
# 48    66    0                2                     146          278
# 52    38    1                2                     138          175
# ..   ...  ...              ...                     ...          ...
# 962   52    1                0                     108          233
# 970   38    1                2                     138          175
# 982   67    0                0                     106          223
# 985   62    1                2                     130          231
# 989   71    0                1                     160          302
#
#      fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# ...

# %%
index_drop_num_major_vessels_1 =df1[(df1['target'] == 1) & df1['num_major_vessels'].isin(num_vessels_list)].index
df1 = df1.drop(index_drop_num_major_vessels_1, axis = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
df1[numerical_features] = scaler.fit_transform(df1[numerical_features])

# %%
df1.head()
# Out:
#         age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0 -0.235473    1                0               -0.346773    -0.653636
# 1 -0.121796    1                0                0.591054    -0.839197
# 2  1.810704    1                0                0.903663    -1.437116
# 3  0.787616    1                0                1.091228    -0.839197
# 4  0.901292    0                0                0.466011     1.037031
#
#    fasting_blood_sugar  resting_electrocardiogram  max_heart_rate_achieved  \
# 0                    0                          1                 0.828245
# 1                    1                          0                 0.263673
# 2                    0                          1                -1.039183
# 3                    0                          1                 0.524245
# 4                    1                          1                -1.864326
#
#    exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# ...

# %%
x=df1.drop('target',axis=1)
y=df1['target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=55)

# %%
from sklearn.svm import SVC
svm_model= SVC()
svm_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred= svm_model.predict(x_test)
pd.DataFrame({'Y_Test':y_test, 'Y_Pred': y_pred}).head(5)
# Out:
#      Y_Test  Y_Pred
# 401       1       1
# 566       1       1
# 354       0       1
# 859       0       0
# 858       1       1

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn import metrics

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9603174603174603

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[123,   6],
#        [  4, 119]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       129
#            1       0.95      0.97      0.96       123
#
#     accuracy                           0.96       252
#    macro avg       0.96      0.96      0.96       252
# weighted avg       0.96      0.96      0.96       252

# %%
from sklearn.model_selection import GridSearchCV

# %%
svm = SVC()
param_grid = {'C':[0.01,0.1,1, 10, 100, 1000],'gamma':[1, 0.1, 0.01, 0.001, 0.0001],'kernel':['linear','rbf']}
grid = GridSearchCV(svm,param_grid, cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']})

# %%
grid.best_estimator_
# Out:
# SVC(C=100, gamma=0.1)

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
y_pred_grid= grid.predict(x_test)

# %%
accuracy_score(y_test, y_pred_grid)
# Out:
# 1.0

# %%
print(classification_report(y_test, y_pred_grid))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       129
#            1       1.00      1.00      1.00       123
#
#     accuracy                           1.00       252
#    macro avg       1.00      1.00      1.00       252
# weighted avg       1.00      1.00      1.00       252
